# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import talib
import pandas as pd
from datetime import datetime
import plotly.graph_objects as go
from tqdm import tqdm
from glob import glob

import plotly
import plotly.offline as py
import plotly.graph_objs as go

# %load_ext autoreload 

# %autoreload 1

# My libs
from src.utils.data_util import DataUtil
from src.strategies.candle_stick import CandleStick
from src.view import visualize_data

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.expand_frame_repr', False)
# Out:
# <style>.container { width:90% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %aimport src.view.visualize_data

# %%
list_cdls = talib.get_function_groups()['Pattern Recognition']

# %%
data_util = DataUtil()
# Selected candlestick patterns initiation
cdl_pattern = CandleStick(list_cdls)

# %%
def sing_day_data(file_path):
    """
    Load single data of data with pre processing (epoch, date string)
    """
    df = pd.read_csv(file_path)
    df = data_util.pre_data_process(df)
    return df

# %%
data = sing_day_data('data/STK/1_min/TSLA/20210723.csv')

# %%
visual = visualize_data.Visualize()

# %%
d = visual.get_candles_visual_data(data)

# %%
d
# Out:
#      date_epoch                                                                                                                cdl_pattern        direction
# 1    1627089660                                                                   BELTHOLD + | CLOSINGMARUBOZU + | LONGLINE + | MARUBOZU +  [ +, 4/4, 100%]
# 10   1627090320                                        DOJI + | DOJISTAR + | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP -   [ +, 4/6, 67%]
# 13   1627090500                                                                                   HIGHWAVE + | SPINNINGTOP + | THRUSTING -   [ +, 2/3, 67%]
# 15   1627090620                          DOJI + | HARAMI - | HARAMICROSS - | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP -   [ -, 4/7, 57%]
# 18   1627090800                                                                     DOJI + | HIGHWAVE - | LONGLEGGEDDOJI + | SPINNINGTOP -   [ +, 2/4, 50%]
# 22   1627091220                                                                   BELTHOLD - | CLOSINGMARUBOZU - | LONGLINE - | MARUBOZU -  [ -, 4/4, 100%]
# 29   1627091640                                                                                       3OUTSIDE - | BELTHOLD - | LONGLINE -  [ -, 3/3, 100%]
# 33   1627091880                                                                   BELTHOLD + | CLOSINGMARUBOZU + | LONGLINE + | MARUBOZU +  [ +, 4/4, 100%]
# 34   1627091940                                                    DOJI + | LONGLEGGEDDOJI + | RICKSHAWMAN + | SHORTLINE + | SPINNINGTOP +  [ +, 5/5, 100%]
# 35   1627092000                                                     DOJI + | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP -   [ +, 3/5, 60%]
# 38   1627092240                                                                               DOJI + | GRAVESTONEDOJI + | LONGLEGGEDDOJI +  [ +, 3/3, 100%]
# 41   1627092420                                                                   BELTHOLD - | CLOSINGMARUBOZU - | LONGLINE - | MARUBOZU -  [ -, 4/4, 100%]
# 44   1627092720                                                                   BELTHOLD - | CLOSINGMARUBOZU - | LONGLINE - | MARUBOZU -  [ -, 4/4, 100%]
# 45   1627092780  DOJI + | DRAGONFLYDOJI + | HAMMER + | HARAMI + | HARAMICROSS + | HIGHWAVE + | LONGLEGGEDDOJI + | SPINNINGTOP + | TAKURI +  [ +, 9/9, 100%]
# 48   1627092960                          DOJI + | HARAMI - | HARAMICROSS - | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP -   [ -, 4/7, 57%]
# 50   1627093080                                                     DOJI + | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP -   [ +, 3/5, 60%]
# 51   1627093140                                                                                      ENGULFING + | HIKKAKE + | SHORTLINE +  [ +, 3/3, 100%]
# 52   1627093260                                                                   BELTHOLD - | CLOSINGMARUBOZU - | LONGLINE - | MARUBOZU -  [ -, 4/4, 100%]
# 55   1627093440                                                                                CLOSINGMARUBOZU + | LONGLINE + | PIERCING +  [ +, 3/3, 100%]
# 59   1627093740                                                     DOJI + | HIGHWAVE + | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP +  [ +, 5/5, 100%]
# 60   1627093800                                                                               CLOSINGMARUBOZU - | ENGULFING - | LONGLINE -  [ -, 3/3, 100%]
# 63   1627093980                                                                                       ENGULFING - | HIKKAKE - | LONGLINE -  [ -, 3/3, 100%]
# 65   1627094100                                                     DOJI + | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP -   [ +, 3/5, 60%]
# 66   1627094160                                                                                  DOJI + | LONGLEGGEDDOJI + | SPINNINGTOP +  [ +, 3/3, 100%]
# 67   1627094220                                                                            GAPSIDESIDEWHITE + | HANGINGMAN - | SHORTLINE +   [ +, 2/3, 67%]
# 70   1627094400                                                                                         3INSIDE - | HIKKAKE + | LONGLINE -   [ -, 2/3, 67%]
# 74   1627094700                                     DOJI + | HIGHWAVE - | LONGLEGGEDDOJI + | MATCHINGLOW + | RICKSHAWMAN + | SPINNINGTOP -   [ +, 4/6, 67%]
# 76   1627094880                                                                     DOJI + | HIGHWAVE + | LONGLEGGEDDOJI + | SPINNINGTOP +  [ +, 4/4, 100%]
# 84   1627095420                                                     DOJI + | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP -   [ +, 3/5, 60%]
# 86   1627095540                          DOJI + | HARAMI - | HARAMICROSS - | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP -   [ -, 4/7, 57%]
# 88   1627095660                                                                                      HARAMI + | HIGHWAVE + | SPINNINGTOP +  [ +, 3/3, 100%]
# 91   1627095960                                                                     DOJI + | DRAGONFLYDOJI + | LONGLEGGEDDOJI + | TAKURI +  [ +, 4/4, 100%]
# 92   1627096140                                                     DOJI + | HIGHWAVE + | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP +  [ +, 5/5, 100%]
# 95   1627096440                                                                   BELTHOLD + | CLOSINGMARUBOZU + | LONGLINE + | MARUBOZU +  [ +, 4/4, 100%]
# 101  1627096860                                                     BELTHOLD - | CLOSINGMARUBOZU - | ENGULFING - | LONGLINE - | MARUBOZU -  [ -, 5/5, 100%]
# 102  1627096920                                                      3OUTSIDE - | BELTHOLD - | CLOSINGMARUBOZU - | LONGLINE - | MARUBOZU -  [ -, 5/5, 100%]
# 107  1627097340                                                     DOJI + | HIGHWAVE + | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP +  [ +, 5/5, 100%]
# 111  1627097580                                        3OUTSIDE + | DOJI + | HIGHWAVE + | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP +  [ +, 6/6, 100%]
# 117  1627098000                                                     BELTHOLD - | CLOSINGMARUBOZU - | ENGULFING - | LONGLINE - | MARUBOZU -  [ -, 5/5, 100%]
# 118  1627098060                                                                                       3OUTSIDE - | HIKKAKE + | SHORTLINE -   [ -, 2/3, 67%]
# 119  1627098120                                                                  DOJI + | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP +  [ +, 4/4, 100%]
# 126  1627098660                                                                                        BELTHOLD - | HIKKAKE + | LONGLINE -   [ -, 2/3, 67%]

# %%
d['annotations']
# Out:
# [{'x': 1627089600, 'label': {'text': 'DOJI + | SHORTLINE + [ +, 2/2, 100%]'}},
#  {'x': 1627089660,
#   'label': {'text': 'BELTHOLD + | CLOSINGMARUBOZU + | LONGLINE + | MARUBOZU + [ +, 4/4, 100%]'}},
#  {'x': 1627089720, 'label': {'text': 'SHORTLINE + [ +, 1/1, 100%]'}},
#  {'x': 1627089780, 'label': {'text': 'DOJI + | SHORTLINE + [ +, 2/2, 100%]'}},
#  {'x': 1627089840, 'label': {'text': 'CLOSINGMARUBOZU + [ +, 1/1, 100%]'}},
#  {'x': 1627089900, 'label': {'text': 'DOJI + | SHORTLINE + [ +, 2/2, 100%]'}},
#  {'x': 1627089960, 'label': {'text': 'CLOSINGMARUBOZU + [ +, 1/1, 100%]'}},
#  {'x': 1627090020,
#   'label': {'text': 'CLOSINGMARUBOZU - | ENGULFING - [ -, 2/2, 100%]'}},
#  {'x': 1627090080,
#   'label': {'text': '3OUTSIDE - | SPINNINGTOP - [ -, 2/2, 100%]'}},
#  {'x': 1627090140,
#   'label': {'text': 'CLOSINGMARUBOZU - | LONGLINE - [ -, 2/2, 100%]'}},
#  {'x': 1627090320,
#   'label': {'text': 'DOJI + | DOJISTAR + | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP - [ +, 4/6, 67%]'}},
#  {'x': 1627090380,
#   'label': {'text': 'HIKKAKE + | SPINNINGTOP - [ +, 1/2, 50%]'}},
#  {'x': 1627090440, 'label': {'text': 'CLOSINGMARUBOZU - [ -, 1/1, 100%]'}},
#  {'x': 1627090500,
#   'label': {'text': 'HIGHWAVE + | SPINNINGTOP + | THRUSTING - [ +, 2/3, 67%]'}},
#  {'x': 1627090560,
#   'label': {'text': 'CLOSINGMARUBOZU + | LONGLINE + [ +, 2/2, 100%]'}},
#  {'x': 1627090620,
#   'label': {'text': 'DOJI + | HARAMI - | HARAMICROSS - | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP - [ -, 4/7, 57%]'}},
#  {'x': 1627090680,
#   'label': {'text': '3INSIDE - | CLOSINGMARUBOZU - [ -, 2/2, 100%]'}},
#  {'x': 1627090740,
#   'label': {'text': 'HARAMI + | SHORTLINE + [ +, 2/2, 100%]'}},
#  {'x': 1627090800,
#   'label': {'text': 'DOJI + | HIGHWAVE - | LONGLEGGEDDOJI + | SPINNINGTOP - [ +, 2/4, 50%]'}},
#  {'x': 1627090860,
#   'label': {'text': 'CLOSINGMARUBOZU + | LONGLINE + [ +, 2/2, 100%]'}},
#  {'x': 1627090920, 'label': {'text': 'SPINNINGTOP - [ -, 1/1, 100%]'}},
#  {'x': 1627090980,
#   'label': {'text': 'HIGHWAVE + | SPINNINGTOP + [ +, 2/2, 100%]'}},
#  {'x': 1627091220,
#   'label': {'text': 'BELTHOLD - | CLOSINGMARUBOZU - | LONGLINE - | MARUBOZU - [ -, 4/4, 100%]'}},
#  {'x': 1627091280,
#   'label': {'text': 'SHORTLINE + | THRUSTING - [ +, 1/2, 50%]'}},
#  {'x': 1627091340, 'label': {'text': 'BELTHOLD - [ -, 1/1, 100%]'}},
#  {'x': 1627091400, 'label': {'text': 'BELTHOLD - [ -, 1/1, 100%]'}},
#  {'x': 1627091460,
#   'label': {'text': 'HIGHWAVE + | SPINNINGTOP + [ +, 2/2, 100%]'}},
#  {'x': 1627091520,
#   'label': {'text': 'CLOSINGMARUBOZU + | MORNINGSTAR + [ +, 2/2, 100%]'}},
#  {'x': 1627091580, 'label': {'text': 'ENGULFING - [ -, 1/1, 100%]'}},
#  {'x': 1627091640,
#   'label': {'text': '3OUTSIDE - | BELTHOLD - | LONGLINE - [ -, 3/3, 100%]'}},
#  {'x': 1627091700, 'label': {'text': 'HARAMI + [ +, 1/1, 100%]'}},
#  {'x': 1627091760,
#   'label': {'text': 'BELTHOLD - | ENGULFING - [ -, 2/2, 100%]'}},
#  {'x': 1627091820, 'label': {'text': '3OUTSIDE - [ -, 1/1, 100%]'}},
#  {'x': 1627091880,
#   'label': {'text': 'BELTHOLD + | CLOSINGMARUBOZU + | LONGLINE + | MARUBOZU + [ +, 4/4, 100%]'}},
#  {'x': 1627091940,
#   'label': {'text': 'DOJI + | LONGLEGGEDDOJI + | RICKSHAWMAN + | SHORTLINE + | SPINNINGTOP + [ +, 5/5, 100%]'}},
#  {'x': 1627092000,
#   'label': {'text': 'DOJI + | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP - [ +, 3/5, 60%]'}},
#  {'x': 1627092120, 'label': {'text': 'LONGLINE + [ +, 1/1, 100%]'}},
#  {'x': 1627092180,
#   'label': {'text': 'BELTHOLD - | ENGULFING - [ -, 2/2, 100%]'}},
#  {'x': 1627092240,
#   'label': {'text': 'DOJI + | GRAVESTONEDOJI + | LONGLEGGEDDOJI + [ +, 3/3, 100%]'}},
#  {'x': 1627092300, 'label': {'text': 'LONGLINE + [ +, 1/1, 100%]'}},
#  {'x': 1627092360,
#   'label': {'text': 'CLOSINGMARUBOZU - | LONGLINE - [ -, 2/2, 100%]'}},
#  {'x': 1627092420,
#   'label': {'text': 'BELTHOLD - | CLOSINGMARUBOZU - | LONGLINE - | MARUBOZU - [ -, 4/4, 100%]'}},
#  {'x': 1627092600, 'label': {'text': 'SHORTLINE - [ -, 1/1, 100%]'}},
#  {'x': 1627092660,
#   'label': {'text': 'HIKKAKE + | SPINNINGTOP - [ +, 1/2, 50%]'}},
#  {'x': 1627092720,
#   'label': {'text': 'BELTHOLD - | CLOSINGMARUBOZU - | LONGLINE - | MARUBOZU - [ -, 4/4, 100%]'}},
#  {'x': 1627092780,
#   'label': {'text': 'DOJI + | DRAGONFLYDOJI + | HAMMER + | HARAMI + | HARAMICROSS + | HIGHWAVE + | LONGLEGGEDDOJI + | SPINNINGTOP + | TAKURI + [ +, 9/9, 100%]'}},
#  {'x': 1627092840, 'label': {'text': 'ENGULFING - [ -, 1/1, 100%]'}},
#  {'x': 1627092900, 'label': {'text': 'ENGULFING + [ +, 1/1, 100%]'}},
#  {'x': 1627092960,
#   'label': {'text': 'DOJI + | HARAMI - | HARAMICROSS - | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP - [ -, 4/7, 57%]'}},
#  {'x': 1627093020,
#   'label': {'text': 'HIKKAKE - | SHOOTINGSTAR - [ -, 2/2, 100%]'}},
#  {'x': 1627093080,
#   'label': {'text': 'DOJI + | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP - [ +, 3/5, 60%]'}},
#  {'x': 1627093140,
#   'label': {'text': 'ENGULFING + | HIKKAKE + | SHORTLINE + [ +, 3/3, 100%]'}},
#  {'x': 1627093260,
#   'label': {'text': 'BELTHOLD - | CLOSINGMARUBOZU - | LONGLINE - | MARUBOZU - [ -, 4/4, 100%]'}},
#  {'x': 1627093320, 'label': {'text': 'HARAMI + [ +, 1/1, 100%]'}},
#  {'x': 1627093380,
#   'label': {'text': 'CLOSINGMARUBOZU - | ENGULFING - [ -, 2/2, 100%]'}},
#  {'x': 1627093440,
#   'label': {'text': 'CLOSINGMARUBOZU + | LONGLINE + | PIERCING + [ +, 3/3, 100%]'}},
#  {'x': 1627093500, 'label': {'text': 'SHORTLINE + [ +, 1/1, 100%]'}},
#  {'x': 1627093560,
#   'label': {'text': 'CLOSINGMARUBOZU - | ENGULFING - [ -, 2/2, 100%]'}},
#  {'x': 1627093620, 'label': {'text': '3OUTSIDE - [ -, 1/1, 100%]'}},
#  {'x': 1627093740,
#   'label': {'text': 'DOJI + | HIGHWAVE + | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP + [ +, 5/5, 100%]'}},
#  {'x': 1627093800,
#   'label': {'text': 'CLOSINGMARUBOZU - | ENGULFING - | LONGLINE - [ -, 3/3, 100%]'}},
#  {'x': 1627093860,
#   'label': {'text': 'HARAMI + | SPINNINGTOP + [ +, 2/2, 100%]'}},
#  {'x': 1627093920, 'label': {'text': 'HIKKAKE - [ -, 1/1, 100%]'}},
#  {'x': 1627093980,
#   'label': {'text': 'ENGULFING - | HIKKAKE - | LONGLINE - [ -, 3/3, 100%]'}},
#  {'x': 1627094040, 'label': {'text': '3OUTSIDE - [ -, 1/1, 100%]'}},
#  {'x': 1627094100,
#   'label': {'text': 'DOJI + | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP - [ +, 3/5, 60%]'}},
#  {'x': 1627094160,
#   'label': {'text': 'DOJI + | LONGLEGGEDDOJI + | SPINNINGTOP + [ +, 3/3, 100%]'}},
#  {'x': 1627094220,
#   'label': {'text': 'GAPSIDESIDEWHITE + | HANGINGMAN - | SHORTLINE + [ +, 2/3, 67%]'}},
#  {'x': 1627094280,
#   'label': {'text': 'BELTHOLD + | LONGLINE + [ +, 2/2, 100%]'}},
#  {'x': 1627094340, 'label': {'text': 'HARAMI - [ -, 1/1, 100%]'}},
#  {'x': 1627094400,
#   'label': {'text': '3INSIDE - | HIKKAKE + | LONGLINE - [ -, 2/3, 67%]'}},
#  {'x': 1627094460, 'label': {'text': 'LONGLINE - [ -, 1/1, 100%]'}},
#  {'x': 1627094520, 'label': {'text': 'SHORTLINE - [ -, 1/1, 100%]'}},
#  {'x': 1627094580,
#   'label': {'text': 'HIKKAKE + | SHORTLINE - [ +, 1/2, 50%]'}},
#  {'x': 1627094700,
#   'label': {'text': 'DOJI + | HIGHWAVE - | LONGLEGGEDDOJI + | MATCHINGLOW + | RICKSHAWMAN + | SPINNINGTOP - [ +, 4/6, 67%]'}},
#  {'x': 1627094820, 'label': {'text': 'SHORTLINE + [ +, 1/1, 100%]'}},
#  {'x': 1627094880,
#   'label': {'text': 'DOJI + | HIGHWAVE + | LONGLEGGEDDOJI + | SPINNINGTOP + [ +, 4/4, 100%]'}},
#  {'x': 1627094940, 'label': {'text': 'ENGULFING - [ -, 1/1, 100%]'}},
#  {'x': 1627095000, 'label': {'text': 'CLOSINGMARUBOZU + [ +, 1/1, 100%]'}},
#  {'x': 1627095060, 'label': {'text': 'HARAMI - [ -, 1/1, 100%]'}},
#  {'x': 1627095120,
#   'label': {'text': '3INSIDE - | BELTHOLD - [ -, 2/2, 100%]'}},
#  {'x': 1627095240, 'label': {'text': 'HIKKAKE - [ -, 1/1, 100%]'}},
#  {'x': 1627095300, 'label': {'text': 'BELTHOLD - [ -, 1/1, 100%]'}},
#  {'x': 1627095360,
#   'label': {'text': 'BELTHOLD + | LONGLINE + [ +, 2/2, 100%]'}},
#  {'x': 1627095420,
#   'label': {'text': 'DOJI + | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP - [ +, 3/5, 60%]'}},
#  {'x': 1627095480, 'label': {'text': 'CLOSINGMARUBOZU + [ +, 1/1, 100%]'}},
#  {'x': 1627095540,
#   'label': {'text': 'DOJI + | HARAMI - | HARAMICROSS - | HIGHWAVE - | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP - [ -, 4/7, 57%]'}},
#  {'x': 1627095600,
#   'label': {'text': 'CLOSINGMARUBOZU - | LONGLINE - [ -, 2/2, 100%]'}},
#  {'x': 1627095660,
#   'label': {'text': 'HARAMI + | HIGHWAVE + | SPINNINGTOP + [ +, 3/3, 100%]'}},
#  {'x': 1627095780,
#   'label': {'text': 'CLOSINGMARUBOZU - | LONGLINE - [ -, 2/2, 100%]'}},
#  {'x': 1627095840, 'label': {'text': 'SHORTLINE - [ -, 1/1, 100%]'}},
#  {'x': 1627095960,
#   'label': {'text': 'DOJI + | DRAGONFLYDOJI + | LONGLEGGEDDOJI + | TAKURI + [ +, 4/4, 100%]'}},
#  {'x': 1627096140,
#   'label': {'text': 'DOJI + | HIGHWAVE + | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP + [ +, 5/5, 100%]'}},
#  {'x': 1627096200, 'label': {'text': 'BELTHOLD + [ +, 1/1, 100%]'}},
#  {'x': 1627096380,
#   'label': {'text': 'CLOSINGMARUBOZU + | LONGLINE + [ +, 2/2, 100%]'}},
#  {'x': 1627096440,
#   'label': {'text': 'BELTHOLD + | CLOSINGMARUBOZU + | LONGLINE + | MARUBOZU + [ +, 4/4, 100%]'}},
#  {'x': 1627096500,
#   'label': {'text': 'BELTHOLD + | LONGLINE + [ +, 2/2, 100%]'}},
#  {'x': 1627096560, 'label': {'text': 'ADVANCEBLOCK - [ -, 1/1, 100%]'}},
#  {'x': 1627096680, 'label': {'text': 'HIKKAKE + | LONGLINE - [ +, 1/2, 50%]'}},
#  {'x': 1627096740, 'label': {'text': 'CLOSINGMARUBOZU - [ -, 1/1, 100%]'}},
#  {'x': 1627096800, 'label': {'text': 'HARAMI + [ +, 1/1, 100%]'}},
#  {'x': 1627096860,
#   'label': {'text': 'BELTHOLD - | CLOSINGMARUBOZU - | ENGULFING - | LONGLINE - | MARUBOZU - [ -, 5/5, 100%]'}},
#  {'x': 1627096920,
#   'label': {'text': '3OUTSIDE - | BELTHOLD - | CLOSINGMARUBOZU - | LONGLINE - | MARUBOZU - [ -, 5/5, 100%]'}},
#  {'x': 1627096980,
#   'label': {'text': 'HARAMI + | SPINNINGTOP + [ +, 2/2, 100%]'}},
#  {'x': 1627097160, 'label': {'text': 'HIKKAKE + [ +, 1/1, 100%]'}},
#  {'x': 1627097220,
#   'label': {'text': 'HIKKAKE + | LONGLINE + [ +, 2/2, 100%]'}},
#  {'x': 1627097280, 'label': {'text': 'HARAMI - [ -, 1/1, 100%]'}},
#  {'x': 1627097340,
#   'label': {'text': 'DOJI + | HIGHWAVE + | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP + [ +, 5/5, 100%]'}},
#  {'x': 1627097400, 'label': {'text': 'HIKKAKE - [ -, 1/1, 100%]'}},
#  {'x': 1627097460, 'label': {'text': 'HARAMI - [ -, 1/1, 100%]'}},
#  {'x': 1627097520,
#   'label': {'text': 'BELTHOLD + | ENGULFING + [ +, 2/2, 100%]'}},
#  {'x': 1627097580,
#   'label': {'text': '3OUTSIDE + | DOJI + | HIGHWAVE + | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP + [ +, 6/6, 100%]'}},
#  {'x': 1627097640,
#   'label': {'text': 'BELTHOLD - | ENGULFING - [ -, 2/2, 100%]'}},
#  {'x': 1627097700,
#   'label': {'text': 'HARAMI + | SHORTLINE + [ +, 2/2, 100%]'}},
#  {'x': 1627097760,
#   'label': {'text': 'HIKKAKE - | SHOOTINGSTAR - [ -, 2/2, 100%]'}},
#  {'x': 1627097820, 'label': {'text': 'ENGULFING - [ -, 1/1, 100%]'}},
#  {'x': 1627097880,
#   'label': {'text': '3OUTSIDE - | HIKKAKE - [ -, 2/2, 100%]'}},
#  {'x': 1627098000,
#   'label': {'text': 'BELTHOLD - | CLOSINGMARUBOZU - | ENGULFING - | LONGLINE - | MARUBOZU - [ -, 5/5, 100%]'}},
#  {'x': 1627098060,
#   'label': {'text': '3OUTSIDE - | HIKKAKE + | SHORTLINE - [ -, 2/3, 67%]'}},
#  {'x': 1627098120,
#   'label': {'text': 'DOJI + | LONGLEGGEDDOJI + | RICKSHAWMAN + | SPINNINGTOP + [ +, 4/4, 100%]'}},
#  {'x': 1627098180,
#   'label': {'text': 'BELTHOLD - | LONGLINE - [ -, 2/2, 100%]'}},
#  {'x': 1627098240, 'label': {'text': 'HAMMER + [ +, 1/1, 100%]'}},
#  {'x': 1627098300, 'label': {'text': 'SPINNINGTOP - [ -, 1/1, 100%]'}},
#  {'x': 1627098360,
#   'label': {'text': 'ENGULFING + | SHORTLINE + [ +, 2/2, 100%]'}},
#  {'x': 1627098480, 'label': {'text': 'SPINNINGTOP + [ +, 1/1, 100%]'}},
#  {'x': 1627098540, 'label': {'text': 'HIKKAKE - [ -, 1/1, 100%]'}},
#  {'x': 1627098660,
#   'label': {'text': 'BELTHOLD - | HIKKAKE + | LONGLINE - [ -, 2/3, 67%]'}},
#  {'x': 1627098780, 'label': {'text': 'CLOSINGMARUBOZU - [ -, 1/1, 100%]'}},
#  {'x': 1627098840, 'label': {'text': 'LONGLINE + [ +, 1/1, 100%]'}},
#  {'x': 1627098960, 'label': {'text': 'SHORTLINE + [ +, 1/1, 100%]'}},
#  {'x': 1627099020, 'label': {'text': 'TASUKIGAP + [ +, 1/1, 100%]'}},
#  {'x': 1627099080, 'label': {'text': 'INVERTEDHAMMER + [ +, 1/1, 100%]'}},
#  {'x': 1627099140,
#   'label': {'text': 'CLOSINGMARUBOZU - | LONGLINE - [ -, 2/2, 100%]'}}]

# %%
dire
# Out:
#      date_epoch        direction
# 0    1627089600  [ +, 2/2, 100%]
# 1    1627089660  [ +, 4/4, 100%]
# 2    1627089720  [ +, 1/1, 100%]
# 3    1627089780  [ +, 2/2, 100%]
# 4    1627089840  [ +, 1/1, 100%]
# 5    1627089900  [ +, 2/2, 100%]
# 6    1627089960  [ +, 1/1, 100%]
# 7    1627090020  [ -, 2/2, 100%]
# 8    1627090080  [ -, 2/2, 100%]
# 9    1627090140  [ -, 2/2, 100%]
# 10   1627090320   [ +, 4/6, 67%]
# 11   1627090380   [ +, 1/2, 50%]
# 12   1627090440  [ -, 1/1, 100%]
# 13   1627090500   [ +, 2/3, 67%]
# 14   1627090560  [ +, 2/2, 100%]
# 15   1627090620   [ -, 4/7, 57%]
# 16   1627090680  [ -, 2/2, 100%]
# 17   1627090740  [ +, 2/2, 100%]
# 18   1627090800   [ +, 2/4, 50%]
# 19   1627090860  [ +, 2/2, 100%]
# 20   1627090920  [ -, 1/1, 100%]
# 21   1627090980  [ +, 2/2, 100%]
# 22   1627091220  [ -, 4/4, 100%]
# 23   1627091280   [ +, 1/2, 50%]
# 24   1627091340  [ -, 1/1, 100%]
# 25   1627091400  [ -, 1/1, 100%]
# 26   1627091460  [ +, 2/2, 100%]
# 27   1627091520  [ +, 2/2, 100%]
# 28   1627091580  [ -, 1/1, 100%]
# 29   1627091640  [ -, 3/3, 100%]
# 30   1627091700  [ +, 1/1, 100%]
# 31   1627091760  [ -, 2/2, 100%]
# 32   1627091820  [ -, 1/1, 100%]
# 33   1627091880  [ +, 4/4, 100%]
# 34   1627091940  [ +, 5/5, 100%]
# 35   1627092000   [ +, 3/5, 60%]
# 36   1627092120  [ +, 1/1, 100%]
# 37   1627092180  [ -, 2/2, 100%]
# 38   1627092240  [ +, 3/3, 100%]
# 39   1627092300  [ +, 1/1, 100%]
# 40   1627092360  [ -, 2/2, 100%]
# 41   1627092420  [ -, 4/4, 100%]
# 42   1627092600  [ -, 1/1, 100%]
# 43   1627092660   [ +, 1/2, 50%]
# 44   1627092720  [ -, 4/4, 100%]
# 45   1627092780  [ +, 9/9, 100%]
# 46   1627092840  [ -, 1/1, 100%]
# 47   1627092900  [ +, 1/1, 100%]
# 48   1627092960   [ -, 4/7, 57%]
# 49   1627093020  [ -, 2/2, 100%]
# 50   1627093080   [ +, 3/5, 60%]
# 51   1627093140  [ +, 3/3, 100%]
# 52   1627093260  [ -, 4/4, 100%]
# 53   1627093320  [ +, 1/1, 100%]
# 54   1627093380  [ -, 2/2, 100%]
# 55   1627093440  [ +, 3/3, 100%]
# 56   1627093500  [ +, 1/1, 100%]
# 57   1627093560  [ -, 2/2, 100%]
# 58   1627093620  [ -, 1/1, 100%]
# 59   1627093740  [ +, 5/5, 100%]
# 60   1627093800  [ -, 3/3, 100%]
# 61   1627093860  [ +, 2/2, 100%]
# 62   1627093920  [ -, 1/1, 100%]
# 63   1627093980  [ -, 3/3, 100%]
# 64   1627094040  [ -, 1/1, 100%]
# 65   1627094100   [ +, 3/5, 60%]
# 66   1627094160  [ +, 3/3, 100%]
# 67   1627094220   [ +, 2/3, 67%]
# 68   1627094280  [ +, 2/2, 100%]
# 69   1627094340  [ -, 1/1, 100%]
# 70   1627094400   [ -, 2/3, 67%]
# 71   1627094460  [ -, 1/1, 100%]
# 72   1627094520  [ -, 1/1, 100%]
# 73   1627094580   [ +, 1/2, 50%]
# 74   1627094700   [ +, 4/6, 67%]
# 75   1627094820  [ +, 1/1, 100%]
# 76   1627094880  [ +, 4/4, 100%]
# 77   1627094940  [ -, 1/1, 100%]
# 78   1627095000  [ +, 1/1, 100%]
# 79   1627095060  [ -, 1/1, 100%]
# 80   1627095120  [ -, 2/2, 100%]
# 81   1627095240  [ -, 1/1, 100%]
# 82   1627095300  [ -, 1/1, 100%]
# 83   1627095360  [ +, 2/2, 100%]
# 84   1627095420   [ +, 3/5, 60%]
# 85   1627095480  [ +, 1/1, 100%]
# 86   1627095540   [ -, 4/7, 57%]
# 87   1627095600  [ -, 2/2, 100%]
# 88   1627095660  [ +, 3/3, 100%]
# 89   1627095780  [ -, 2/2, 100%]
# 90   1627095840  [ -, 1/1, 100%]
# 91   1627095960  [ +, 4/4, 100%]
# 92   1627096140  [ +, 5/5, 100%]
# 93   1627096200  [ +, 1/1, 100%]
# 94   1627096380  [ +, 2/2, 100%]
# 95   1627096440  [ +, 4/4, 100%]
# 96   1627096500  [ +, 2/2, 100%]
# 97   1627096560  [ -, 1/1, 100%]
# 98   1627096680   [ +, 1/2, 50%]
# 99   1627096740  [ -, 1/1, 100%]
# 100  1627096800  [ +, 1/1, 100%]
# 101  1627096860  [ -, 5/5, 100%]
# 102  1627096920  [ -, 5/5, 100%]
# 103  1627096980  [ +, 2/2, 100%]
# 104  1627097160  [ +, 1/1, 100%]
# 105  1627097220  [ +, 2/2, 100%]
# 106  1627097280  [ -, 1/1, 100%]
# 107  1627097340  [ +, 5/5, 100%]
# 108  1627097400  [ -, 1/1, 100%]
# 109  1627097460  [ -, 1/1, 100%]
# 110  1627097520  [ +, 2/2, 100%]
# 111  1627097580  [ +, 6/6, 100%]
# 112  1627097640  [ -, 2/2, 100%]
# 113  1627097700  [ +, 2/2, 100%]
# 114  1627097760  [ -, 2/2, 100%]
# 115  1627097820  [ -, 1/1, 100%]
# 116  1627097880  [ -, 2/2, 100%]
# 117  1627098000  [ -, 5/5, 100%]
# 118  1627098060   [ -, 2/3, 67%]
# 119  1627098120  [ +, 4/4, 100%]
# 120  1627098180  [ -, 2/2, 100%]
# 121  1627098240  [ +, 1/1, 100%]
# 122  1627098300  [ -, 1/1, 100%]
# 123  1627098360  [ +, 2/2, 100%]
# 124  1627098480  [ +, 1/1, 100%]
# 125  1627098540  [ -, 1/1, 100%]
# 126  1627098660   [ -, 2/3, 67%]
# 127  1627098780  [ -, 1/1, 100%]
# 128  1627098840  [ +, 1/1, 100%]
# 129  1627098960  [ +, 1/1, 100%]
# 130  1627099020  [ +, 1/1, 100%]
# 131  1627099080  [ +, 1/1, 100%]
# 132  1627099140  [ -, 2/2, 100%]

# %%
cdl = cdl.merge(dire, on='date_epoch')

# %%
cdl.values[0][1]
# Out:
# 'DOJI + | SHORTLINE +'
